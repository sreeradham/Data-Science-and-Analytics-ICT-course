# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeradham/Data-Science-and-Analytics-ICT-course/blob/main/Sreeradha_M_ICT_activity_Diamonds_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('/content/sample_data/diamonds_new.csv')

# %%
data.head()
# Out:
#    carat      cut color clarity  table     x     y     z  price_new
# 0   0.23    Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1   0.21  Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2   0.23     Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3   0.29  Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4   0.31     Good     J     SI2   58.0  4.34  4.35  2.75      167.5

# %%
#check missing values
data.isna().sum()
# Out:
# carat        99
# cut           0
# color        56
# clarity       0
# table        63
# x             0
# y             0
# z             0
# price_new     0
# dtype: int64

# %%
data.dtypes
# Out:
# carat        float64
# cut           object
# color         object
# clarity       object
# table        float64
# x            float64
# y            float64
# z            float64
# price_new    float64
# dtype: object

# %%
data.hist(figsize=(20,15))
plt.show()

# %%
#need to use median
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'table', 'x', 'y', 'z',
#        'price_new'],
#       dtype='object')
